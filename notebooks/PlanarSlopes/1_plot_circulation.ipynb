# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import xarray as xr
from xmitgcm import open_mdsdataset 
from xhistogram.xarray import histogram

from matplotlib import pyplot as plt

# %%
Γ = 0.0008613659531090722
g = 9.81
α = 2.e-4

N = np.sqrt(g*α*Γ)
θ = 1.26E-3
f = 5.3e-5

h = 230
k0 = 5.2e-5
k1 = 1.8e-3

dx = 300.
delta_t = 10.

# %%
data_dir = f"../../MITgcm/experiments/rotated_BBTRE_idealized-plane-hires/run/"
ds = open_mdsdataset(data_dir,ignore_unknown_vars=True,prefix=["budgetDiag"], delta_t=delta_t)

# %%
ds['WVEL'].isel(time=-1, Zl=-10).plot()
